# %%
import pandas as pd

# %% [markdown]
# # READ ALL DATA FROM SQL

# %%
from sqlalchemy import create_engine
import pymysql
sqlEngine = create_engine('mysql+pymysql://root:security@127.0.0.1:3306/LifeExpectancy')

# %%
df1 = pd.read_sql("select * from finall", sqlEngine.connect());

# %%
df1.drop('GDP per capita',axis=1,inplace=True)

# %%
df1
# Out:
#         Year  Total Population, as of 1 July (thousands)  \
# 0     1990.0                                    5483.793
# 1     1991.0                                    5594.828
# 2     1992.0                                    5743.085
# 3     1993.0                                    5555.220
# 4     1994.0                                    5586.408
# ...      ...                                         ...
# 7547  2017.0                                      11.936
# 7548  2018.0                                      11.816
# 7549  2019.0                                      11.714
# 7550  2020.0                                      11.655
# 7551  2021.0                                      11.627
#
#       Population Growth Rate (percentage)  Births (thousands)  \
# 0                                   2.029             256.200
# 1                                   1.981             259.010
# 2                                   3.234             261.676
# ...

# %% [markdown]
# # READ FEATURE CSV ONE BY ONE

# %%
df = pd.read_csv('6maddison-data-gdp-per-capita-in-2011us.csv')

# %%
df = df[df['Year']>=1990]

# %%
df.drop('417485-annotations',axis=1,inplace=True)

# %%
df
# Out:
#             Entity  Year  GDP per capita
# 40     Afghanistan  1990        963.0000
# 41     Afghanistan  1991        881.1704
# 42     Afghanistan  1992        843.8753
# 43     Afghanistan  1993        578.4027
# 44     Afghanistan  1994        428.4246
# ...            ...   ...             ...
# 19871     Zimbabwe  2014       1594.0000
# 19872     Zimbabwe  2015       1560.0000
# 19873     Zimbabwe  2016       1534.0000
# 19874     Zimbabwe  2017       1582.3662
# 19875     Zimbabwe  2018       1611.4052
#
# [4953 rows x 3 columns]

# %% [markdown]
# # MERGE FEATURE

# %%
df_cd = pd.merge(df1, df, how='left', left_on =['Region, subregion, country or area *','Year'], right_on = ['Entity','Year'])

# %%
df_cd.drop('Entity',axis=1,inplace=True)

# %%
df_cd
# Out:
#         Year  Total Population, as of 1 July (thousands)  \
# 0     1990.0                                    5483.793
# 1     1991.0                                    5594.828
# 2     1992.0                                    5743.085
# 3     1993.0                                    5555.220
# 4     1994.0                                    5586.408
# ...      ...                                         ...
# 7547  2017.0                                      11.936
# 7548  2018.0                                      11.816
# 7549  2019.0                                      11.714
# 7550  2020.0                                      11.655
# 7551  2021.0                                      11.627
#
#       Population Growth Rate (percentage)  Births (thousands)  \
# 0                                   2.029             256.200
# 1                                   1.981             259.010
# 2                                   3.234             261.676
# ...

# %%
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7552 entries, 0 to 7551
# Data columns (total 21 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Year                                              7552 non-null   float64
#  1   Total Population, as of 1 July (thousands)        7552 non-null   float64
#  2   Population Growth Rate (percentage)               7552 non-null   float64
#  3   Births (thousands)                                7552 non-null   float64
#  4   Crude Birth Rate (births per 1,000 population)    7552 non-null   float64
#  5   Total Deaths (thousands)                          7552 non-null   float64
#  6   Life Expectancy at Birth, both sexes (years)      7552 non-null   float64
#  7   Infant Deaths, under age 1 (thousands)            7552 non-null   float64
#  8   Net Number of Migrants (thousands)                7552 non-null   float64
# ...

# %% [markdown]
# # WRITE TO SQL

# %%
df_cd.to_sql('finall', sqlEngine.connect(), index=False)
# Out:
# 7552
