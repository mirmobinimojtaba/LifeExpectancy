# %%
import pandas as pd

# %%
df = pd.read_csv('13share-of-individuals-using-the-internet.csv')

# %%
df = df[df['Year']>=1990]

# %%
df.drop('Code',axis=1,inplace=True)

# %%
df
# Out:
#             Entity  Year  GDP per capita
# 0      Afghanistan  1950       1156.0000
# 1      Afghanistan  1951       1170.0000
# 2      Afghanistan  1952       1189.0000
# 3      Afghanistan  1953       1240.0000
# 4      Afghanistan  1954       1245.0000
# ...            ...   ...             ...
# 11221     Zimbabwe  2014       1594.0000
# 11222     Zimbabwe  2015       1560.0000
# 11223     Zimbabwe  2016       1534.0000
# 11224     Zimbabwe  2017       1582.3662
# 11225     Zimbabwe  2018       1611.4052
#
# [11226 rows x 3 columns]

# %%
from sqlalchemy import create_engine
import pymysql
sqlEngine = create_engine('mysql+pymysql://root:security@127.0.0.1:3306/LifeExpectancy')

# %%
df = pd.read_sql("select * from gdp", sqlEngine.connect());

# %%
df1
# Out:
#         Year  Total Population, as of 1 July (thousands)  \
# 0     1998.0                                    6035.340
# 1     1999.0                                    6180.180
# 2     2000.0                                    6307.659
# 3     2001.0                                    6465.729
# 4     2002.0                                    6648.938
# ...      ...                                         ...
# 7547  2017.0                                      11.936
# 7548  2018.0                                      11.816
# 7549  2019.0                                      11.714
# 7550  2020.0                                      11.655
# 7551  2021.0                                      11.627
#
#       Population Growth Rate (percentage)  Births (thousands)  \
# 0                                   2.697             249.258
# 1                                   2.054             260.402
# 2                                   2.030             268.825
# ...

# %%
df_cd = pd.merge(df1, df, how='left', left_on =['Region, subregion, country or area *','Year'], right_on = ['Entity','Year'])

# %%
df_cd.drop('Entity',axis=1,inplace=True)

# %%
df_cd.rename(columns={'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)': 'Deaths - Alcohol'}, inplace=True)

# %%
df_cd
# Out:
#         Year  Total Population, as of 1 July (thousands)  \
# 0     1998.0                                    6035.340
# 1     1999.0                                    6180.180
# 2     2000.0                                    6307.659
# 3     2001.0                                    6465.729
# 4     2002.0                                    6648.938
# ...      ...                                         ...
# 7547  2017.0                                      11.936
# 7548  2018.0                                      11.816
# 7549  2019.0                                      11.714
# 7550  2020.0                                      11.655
# 7551  2021.0                                      11.627
#
#       Population Growth Rate (percentage)  Births (thousands)  \
# 0                                   2.697             249.258
# 1                                   2.054             260.402
# 2                                   2.030             268.825
# ...

# %%
len(df_cd['Region, subregion, country or area *'].unique())
# Out:
# 236

# %%
df_cd.to_sql('final', sqlEngine.connect(), index=False)
# Out:
# 7552

# %%
df = pd.read_sql("select * from final", sqlEngine.connect());

# %%
df.to_csv('test.csv')

# %%
df_cd.to_sql('finallnonull1', sqlEngine.connect(), index=False)
# Out:
# 7552
